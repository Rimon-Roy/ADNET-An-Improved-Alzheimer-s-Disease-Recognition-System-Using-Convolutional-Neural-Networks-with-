# %% [markdown]
# # Alzheimer's diseases detection using ResNet50 pre-trained model.

# %% [markdown]
# ## Import Packages

# %%
import os
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
from PIL import Image
import tensorflow as tf
import keras_cv
from tensorflow.data import AUTOTUNE
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.layers import (
    RandomBrightness, RandomZoom, RandomFlip,
    Input, Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend

# %%
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Flatten, Input, concatenate
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint
import tensorflow as tf
import os

# %% [markdown]
# ## Load the Dataset

# %%
X_loaded = np.load('/kaggle/input/alzheimer/X_final.npy')
Y_loaded = np.load('/kaggle/input/alzheimer/Y_final.npy')

# %% [markdown]
# ## Reshape and Convert to RGB images

# %%
# Reshape the grayscale data to (num_samples, height, width, channels)
X_loaded_resized = np.resize(X_loaded, (len(X_loaded), 150, 150, 1))

# Replicate the single channel to create three channels
X_loaded_rgb = np.repeat(X_loaded_resized, 3, axis=-1)

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_loaded_rgb, Y_loaded, random_state=42)
X_train.shape
# Out:
# (6400, 150, 150, 3)

# %%
mean = np.mean(X_train)
std = np.std(X_train)

X_train = ((X_train - mean) / std).astype(np.float32)

# %% [markdown]
# ## Spliting Dataset into Training and Testing data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Training data augmentation

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(
featurewise_center=False,
samplewise_center=False,
featurewise_std_normalization=False,
samplewise_std_normalization=False,
zca_whitening=False,
rotation_range=10,
zoom_range=0.2,
width_shift_range=0.2,
horizontal_flip=False,
vertical_flip=False)

datagen.fit(X_train)

# %% [markdown]
# ## ResNet50 Model

# %% [markdown]
# ### Load the pre-trained ResNet50 model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, BatchNormalization, Dropout, Dense, concatenate, Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint
import tensorflow as tf
import os

# Load the ResNet50 model without the fully connected layers
conv_base = ResNet50(include_top=False, weights='imagenet', input_shape=(150, 150, 3))
conv_base.trainable = False

# Additional layers
additional_model = Sequential()
additional_model.add(Flatten())
additional_model.add(BatchNormalization())
additional_model.add(Dropout(0.25))
additional_model.add(Dense(512, activation='relu'))
additional_model.add(BatchNormalization())
additional_model.add(Dropout(0.5))
additional_model.add(Dense(4, activation='softmax'))

# Create an input tensor for the ResNet50 base
resnet_input = Input(shape=(150, 150, 3))

# Connect the ResNet50 base
resnet_output = conv_base(resnet_input)

# Flatten the ResNet50 output
resnet_output_flatten = Flatten()(resnet_output)

# Connect the ResNet50 output with the output of the additional layers
combined_output = concatenate([resnet_output_flatten, additional_model(resnet_input)])

# Final output layer
output = Dense(4, activation='softmax')(combined_output)

# Create the combined model
combined_model = Model(inputs=resnet_input, outputs=output)

# Compile the model
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.1)
combined_model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Define the directory to save the model weights
save_dir = '/kaggle/working/'
model_name = 'alzheimers_combined_model.h5'
model_path = os.path.join(save_dir, model_name)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.8, patience=10)
tensorboard = TensorBoard(log_dir='logs')
checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', save_best_only=True, mode='auto', verbose=1)

# Assuming X_train is your ResNet50 input data
# Replace X_train with your actual data
history = combined_model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.2, callbacks=[reduce_lr, tensorboard, checkpoint])
# Out:
# Epoch 1/150
# 127/128 [============================>.] - ETA: 0s - loss: 1.0056 - accuracy: 0.5468
# Epoch 1: val_accuracy improved from -inf to 0.48242, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 15s 75ms/step - loss: 1.0054 - accuracy: 0.5469 - val_loss: 1.2865 - val_accuracy: 0.4824 - lr: 0.0010
# Epoch 2/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.8930 - accuracy: 0.6058
# Epoch 2: val_accuracy improved from 0.48242 to 0.55371, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.8918 - accuracy: 0.6067 - val_loss: 1.1340 - val_accuracy: 0.5537 - lr: 0.0010
# Epoch 3/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.7719 - accuracy: 0.6629
# Epoch 3: val_accuracy improved from 0.55371 to 0.69824, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.7720 - accuracy: 0.6619 - val_loss: 0.7234 - val_accuracy: 0.6982 - lr: 0.0010
# Epoch 4/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.6868
# Epoch 4: val_accuracy did not improve from 0.69824
# 128/128 [==============================] - 6s 46ms/step - loss: 0.7112 - accuracy: 0.6855 - val_loss: 0.8137 - val_accuracy: 0.6455 - lr: 0.0010
# Epoch 5/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.7133
# Epoch 5: val_accuracy improved from 0.69824 to 0.72461, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.6727 - accuracy: 0.7131 - val_loss: 0.6386 - val_accuracy: 0.7246 - lr: 0.0010
# Epoch 6/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5937 - accuracy: 0.7520
# Epoch 6: val_accuracy did not improve from 0.72461
# 128/128 [==============================] - 6s 46ms/step - loss: 0.5935 - accuracy: 0.7520 - val_loss: 0.7232 - val_accuracy: 0.6777 - lr: 0.0010
# Epoch 7/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7736
# Epoch 7: val_accuracy improved from 0.72461 to 0.75879, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.5454 - accuracy: 0.7734 - val_loss: 0.5856 - val_accuracy: 0.7588 - lr: 0.0010
# Epoch 8/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5135 - accuracy: 0.7938
# Epoch 8: val_accuracy improved from 0.75879 to 0.77637, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.5129 - accuracy: 0.7939 - val_loss: 0.5532 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 9/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4775 - accuracy: 0.8100
# Epoch 9: val_accuracy did not improve from 0.77637
# 128/128 [==============================] - 6s 46ms/step - loss: 0.4786 - accuracy: 0.8091 - val_loss: 0.5566 - val_accuracy: 0.7686 - lr: 0.0010
# Epoch 10/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4534 - accuracy: 0.8356
# Epoch 10: val_accuracy improved from 0.77637 to 0.80566, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.4551 - accuracy: 0.8345 - val_loss: 0.5157 - val_accuracy: 0.8057 - lr: 0.0010
# Epoch 11/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4602 - accuracy: 0.8191
# Epoch 11: val_accuracy did not improve from 0.80566
# 128/128 [==============================] - 6s 46ms/step - loss: 0.4596 - accuracy: 0.8191 - val_loss: 0.4949 - val_accuracy: 0.8047 - lr: 0.0010
# Epoch 12/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3982 - accuracy: 0.8504
# Epoch 12: val_accuracy did not improve from 0.80566
# 128/128 [==============================] - 6s 46ms/step - loss: 0.3975 - accuracy: 0.8508 - val_loss: 0.6357 - val_accuracy: 0.7148 - lr: 0.0010
# Epoch 13/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3942 - accuracy: 0.8474
# Epoch 13: val_accuracy did not improve from 0.80566
# 128/128 [==============================] - 6s 46ms/step - loss: 0.3945 - accuracy: 0.8472 - val_loss: 0.4986 - val_accuracy: 0.7959 - lr: 0.0010
# Epoch 14/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3644 - accuracy: 0.8696
# Epoch 14: val_accuracy improved from 0.80566 to 0.85254, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.3641 - accuracy: 0.8696 - val_loss: 0.4361 - val_accuracy: 0.8525 - lr: 0.0010
# Epoch 15/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3412 - accuracy: 0.8893
# Epoch 15: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.3417 - accuracy: 0.8887 - val_loss: 0.5076 - val_accuracy: 0.7998 - lr: 0.0010
# Epoch 16/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3281 - accuracy: 0.8866
# Epoch 16: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.3290 - accuracy: 0.8860 - val_loss: 0.4806 - val_accuracy: 0.8145 - lr: 0.0010
# Epoch 17/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3231 - accuracy: 0.8853
# Epoch 17: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.3231 - accuracy: 0.8860 - val_loss: 0.3946 - val_accuracy: 0.8457 - lr: 0.0010
# Epoch 18/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2758 - accuracy: 0.9166
# Epoch 18: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.2765 - accuracy: 0.9167 - val_loss: 0.4567 - val_accuracy: 0.8135 - lr: 0.0010
# Epoch 19/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2730 - accuracy: 0.9176
# Epoch 19: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.2734 - accuracy: 0.9175 - val_loss: 0.4608 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 20/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2896 - accuracy: 0.8981
# Epoch 20: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.2894 - accuracy: 0.8984 - val_loss: 0.4165 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 21/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2351 - accuracy: 0.9380
# Epoch 21: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.2346 - accuracy: 0.9382 - val_loss: 0.4234 - val_accuracy: 0.8330 - lr: 0.0010
# Epoch 22/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2228 - accuracy: 0.9405
# Epoch 22: val_accuracy did not improve from 0.85254
# 128/128 [==============================] - 6s 46ms/step - loss: 0.2224 - accuracy: 0.9404 - val_loss: 0.4758 - val_accuracy: 0.8066 - lr: 0.0010
# Epoch 23/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2217 - accuracy: 0.9385
# Epoch 23: val_accuracy improved from 0.85254 to 0.86035, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2216 - accuracy: 0.9382 - val_loss: 0.3726 - val_accuracy: 0.8604 - lr: 0.0010
# Epoch 24/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2176 - accuracy: 0.9355
# Epoch 24: val_accuracy improved from 0.86035 to 0.89062, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.2175 - accuracy: 0.9360 - val_loss: 0.3252 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 25/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1947 - accuracy: 0.9540
# Epoch 25: val_accuracy did not improve from 0.89062
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1942 - accuracy: 0.9543 - val_loss: 0.3368 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 26/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1757 - accuracy: 0.9631
# Epoch 26: val_accuracy improved from 0.89062 to 0.91113, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1755 - accuracy: 0.9631 - val_loss: 0.2947 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 27/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1624 - accuracy: 0.9685
# Epoch 27: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1625 - accuracy: 0.9685 - val_loss: 0.3385 - val_accuracy: 0.8701 - lr: 0.0010
# Epoch 28/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1550 - accuracy: 0.9729
# Epoch 28: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1554 - accuracy: 0.9729 - val_loss: 0.3049 - val_accuracy: 0.8867 - lr: 0.0010
# Epoch 29/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1475 - accuracy: 0.9751
# Epoch 29: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1474 - accuracy: 0.9753 - val_loss: 0.2783 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 30/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1475 - accuracy: 0.9744
# Epoch 30: val_accuracy improved from 0.91113 to 0.91211, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1470 - accuracy: 0.9746 - val_loss: 0.2670 - val_accuracy: 0.9121 - lr: 0.0010
# Epoch 31/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1487 - accuracy: 0.9722
# Epoch 31: val_accuracy did not improve from 0.91211
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1489 - accuracy: 0.9722 - val_loss: 0.3021 - val_accuracy: 0.9023 - lr: 0.0010
# Epoch 32/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9756
# Epoch 32: val_accuracy did not improve from 0.91211
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1389 - accuracy: 0.9753 - val_loss: 0.3417 - val_accuracy: 0.8770 - lr: 0.0010
# Epoch 33/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9719
# Epoch 33: val_accuracy did not improve from 0.91211
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1369 - accuracy: 0.9722 - val_loss: 0.2802 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 34/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1524 - accuracy: 0.9638
# Epoch 34: val_accuracy improved from 0.91211 to 0.92578, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 63ms/step - loss: 0.1519 - accuracy: 0.9641 - val_loss: 0.2452 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 35/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9786
# Epoch 35: val_accuracy did not improve from 0.92578
# 128/128 [==============================] - 6s 47ms/step - loss: 0.1237 - accuracy: 0.9788 - val_loss: 0.2939 - val_accuracy: 0.8926 - lr: 0.0010
# Epoch 36/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9830
# Epoch 36: val_accuracy improved from 0.92578 to 0.92969, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.1111 - accuracy: 0.9832 - val_loss: 0.2383 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 37/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9825
# Epoch 37: val_accuracy did not improve from 0.92969
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1106 - accuracy: 0.9827 - val_loss: 0.2329 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 38/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0937 - accuracy: 0.9916
# Epoch 38: val_accuracy did not improve from 0.92969
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0937 - accuracy: 0.9917 - val_loss: 0.2568 - val_accuracy: 0.9180 - lr: 0.0010
# Epoch 39/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9850
# Epoch 39: val_accuracy did not improve from 0.92969
# 128/128 [==============================] - 6s 46ms/step - loss: 0.1047 - accuracy: 0.9851 - val_loss: 0.2347 - val_accuracy: 0.9229 - lr: 0.0010
# Epoch 40/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0909 - accuracy: 0.9924
# Epoch 40: val_accuracy did not improve from 0.92969
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0918 - accuracy: 0.9919 - val_loss: 0.2232 - val_accuracy: 0.9238 - lr: 0.0010
# Epoch 41/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0938 - accuracy: 0.9897
# Epoch 41: val_accuracy did not improve from 0.92969
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0934 - accuracy: 0.9897 - val_loss: 0.2324 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 42/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0916 - accuracy: 0.9887
# Epoch 42: val_accuracy improved from 0.92969 to 0.93457, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0916 - accuracy: 0.9885 - val_loss: 0.2191 - val_accuracy: 0.9346 - lr: 0.0010
# Epoch 43/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9921
# Epoch 43: val_accuracy did not improve from 0.93457
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0824 - accuracy: 0.9919 - val_loss: 0.2342 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 44/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9948
# Epoch 44: val_accuracy did not improve from 0.93457
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0768 - accuracy: 0.9949 - val_loss: 0.2472 - val_accuracy: 0.9180 - lr: 0.0010
# Epoch 45/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9904
# Epoch 45: val_accuracy did not improve from 0.93457
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0855 - accuracy: 0.9902 - val_loss: 0.2254 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 46/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0780 - accuracy: 0.9936
# Epoch 46: val_accuracy did not improve from 0.93457
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0778 - accuracy: 0.9937 - val_loss: 0.2281 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 47/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9946
# Epoch 47: val_accuracy did not improve from 0.93457
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0736 - accuracy: 0.9946 - val_loss: 0.2351 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 48/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0722 - accuracy: 0.9961
# Epoch 48: val_accuracy did not improve from 0.93457
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0722 - accuracy: 0.9961 - val_loss: 0.2117 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 49/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9970
# Epoch 49: val_accuracy improved from 0.93457 to 0.93945, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0663 - accuracy: 0.9971 - val_loss: 0.2073 - val_accuracy: 0.9395 - lr: 0.0010
# Epoch 50/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9973
# Epoch 50: val_accuracy did not improve from 0.93945
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0615 - accuracy: 0.9973 - val_loss: 0.2363 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 51/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0688 - accuracy: 0.9946
# Epoch 51: val_accuracy did not improve from 0.93945
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0686 - accuracy: 0.9946 - val_loss: 0.2152 - val_accuracy: 0.9268 - lr: 0.0010
# Epoch 52/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9966
# Epoch 52: val_accuracy did not improve from 0.93945
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0633 - accuracy: 0.9966 - val_loss: 0.2086 - val_accuracy: 0.9277 - lr: 0.0010
# Epoch 53/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9948
# Epoch 53: val_accuracy did not improve from 0.93945
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0685 - accuracy: 0.9949 - val_loss: 0.1950 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 54/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9985
# Epoch 54: val_accuracy did not improve from 0.93945
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0541 - accuracy: 0.9985 - val_loss: 0.2034 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 55/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9988
# Epoch 55: val_accuracy improved from 0.93945 to 0.94141, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0544 - accuracy: 0.9988 - val_loss: 0.1900 - val_accuracy: 0.9414 - lr: 0.0010
# Epoch 56/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9980
# Epoch 56: val_accuracy did not improve from 0.94141
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0539 - accuracy: 0.9980 - val_loss: 0.2613 - val_accuracy: 0.9072 - lr: 0.0010
# Epoch 57/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0535 - accuracy: 0.9983
# Epoch 57: val_accuracy did not improve from 0.94141
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0535 - accuracy: 0.9983 - val_loss: 0.2003 - val_accuracy: 0.9355 - lr: 0.0010
# Epoch 58/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9906
# Epoch 58: val_accuracy improved from 0.94141 to 0.94336, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.0740 - accuracy: 0.9907 - val_loss: 0.1830 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 59/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9970
# Epoch 59: val_accuracy improved from 0.94336 to 0.94629, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.0544 - accuracy: 0.9971 - val_loss: 0.1833 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 60/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9956
# Epoch 60: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0560 - accuracy: 0.9956 - val_loss: 0.1927 - val_accuracy: 0.9326 - lr: 0.0010
# Epoch 61/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.9968
# Epoch 61: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0515 - accuracy: 0.9968 - val_loss: 0.1796 - val_accuracy: 0.9424 - lr: 0.0010
# Epoch 62/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9998
# Epoch 62: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0440 - accuracy: 0.9998 - val_loss: 0.1868 - val_accuracy: 0.9395 - lr: 0.0010
# Epoch 63/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9985
# Epoch 63: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0427 - accuracy: 0.9985 - val_loss: 0.1761 - val_accuracy: 0.9443 - lr: 0.0010
# Epoch 64/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9990
# Epoch 64: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0440 - accuracy: 0.9990 - val_loss: 0.1746 - val_accuracy: 0.9453 - lr: 0.0010
# Epoch 65/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9990
# Epoch 65: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0415 - accuracy: 0.9990 - val_loss: 0.2064 - val_accuracy: 0.9355 - lr: 0.0010
# Epoch 66/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0468 - accuracy: 0.9985
# Epoch 66: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0468 - accuracy: 0.9985 - val_loss: 0.1946 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 67/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9990
# Epoch 67: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0472 - accuracy: 0.9990 - val_loss: 0.1792 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 68/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9990
# Epoch 68: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0458 - accuracy: 0.9990 - val_loss: 0.1784 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 69/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9985
# Epoch 69: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0447 - accuracy: 0.9983 - val_loss: 0.1737 - val_accuracy: 0.9443 - lr: 0.0010
# Epoch 70/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0380 - accuracy: 0.9988
# Epoch 70: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0380 - accuracy: 0.9988 - val_loss: 0.1770 - val_accuracy: 0.9395 - lr: 8.0000e-04
# Epoch 71/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9993
# Epoch 71: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0367 - accuracy: 0.9993 - val_loss: 0.1728 - val_accuracy: 0.9424 - lr: 8.0000e-04
# Epoch 72/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9395 - lr: 8.0000e-04
# Epoch 73/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9238 - lr: 8.0000e-04
# Epoch 74/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9995
# Epoch 74: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0378 - accuracy: 0.9995 - val_loss: 0.1710 - val_accuracy: 0.9434 - lr: 8.0000e-04
# Epoch 75/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0335 - accuracy: 0.9995
# Epoch 75: val_accuracy did not improve from 0.94629
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0334 - accuracy: 0.9995 - val_loss: 0.1845 - val_accuracy: 0.9463 - lr: 8.0000e-04
# Epoch 76/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9998
# Epoch 76: val_accuracy improved from 0.94629 to 0.94727, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.0331 - accuracy: 0.9998 - val_loss: 0.1623 - val_accuracy: 0.9473 - lr: 8.0000e-04
# Epoch 77/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9998
# Epoch 77: val_accuracy did not improve from 0.94727
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0331 - accuracy: 0.9998 - val_loss: 0.1751 - val_accuracy: 0.9443 - lr: 8.0000e-04
# Epoch 78/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.94727
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9473 - lr: 8.0000e-04
# Epoch 79/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.94727
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9463 - lr: 8.0000e-04
# Epoch 80/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.94727
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9434 - lr: 8.0000e-04
# Epoch 81/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9998
# Epoch 81: val_accuracy did not improve from 0.94727
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0340 - accuracy: 0.9998 - val_loss: 0.1867 - val_accuracy: 0.9375 - lr: 8.0000e-04
# Epoch 82/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9998
# Epoch 82: val_accuracy improved from 0.94727 to 0.94922, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0316 - accuracy: 0.9998 - val_loss: 0.1606 - val_accuracy: 0.9492 - lr: 8.0000e-04
# Epoch 83/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9998
# Epoch 83: val_accuracy did not improve from 0.94922
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0309 - accuracy: 0.9998 - val_loss: 0.1689 - val_accuracy: 0.9443 - lr: 8.0000e-04
# Epoch 84/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.94922
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9482 - lr: 8.0000e-04
# Epoch 85/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9998
# Epoch 85: val_accuracy did not improve from 0.94922
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0326 - accuracy: 0.9998 - val_loss: 0.1683 - val_accuracy: 0.9453 - lr: 8.0000e-04
# Epoch 86/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9998
# Epoch 86: val_accuracy did not improve from 0.94922
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0288 - accuracy: 0.9998 - val_loss: 0.1553 - val_accuracy: 0.9473 - lr: 8.0000e-04
# Epoch 87/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0287 - accuracy: 0.9995
# Epoch 87: val_accuracy improved from 0.94922 to 0.95020, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 59ms/step - loss: 0.0286 - accuracy: 0.9995 - val_loss: 0.1541 - val_accuracy: 0.9502 - lr: 8.0000e-04
# Epoch 88/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9998
# Epoch 88: val_accuracy improved from 0.95020 to 0.95312, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0273 - accuracy: 0.9998 - val_loss: 0.1650 - val_accuracy: 0.9531 - lr: 8.0000e-04
# Epoch 89/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9482 - lr: 8.0000e-04
# Epoch 90/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9385 - lr: 8.0000e-04
# Epoch 91/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9998
# Epoch 91: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0265 - accuracy: 0.9998 - val_loss: 0.1648 - val_accuracy: 0.9502 - lr: 8.0000e-04
# Epoch 92/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9502 - lr: 8.0000e-04
# Epoch 93/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9473 - lr: 8.0000e-04
# Epoch 94/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9502 - lr: 8.0000e-04
# Epoch 95/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9492 - lr: 8.0000e-04
# Epoch 96/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9998
# Epoch 96: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0260 - accuracy: 0.9998 - val_loss: 0.1657 - val_accuracy: 0.9502 - lr: 8.0000e-04
# Epoch 97/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9482 - lr: 8.0000e-04
# Epoch 98/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9463 - lr: 8.0000e-04
# Epoch 99/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9521 - lr: 6.4000e-04
# Epoch 100/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9453 - lr: 6.4000e-04
# Epoch 101/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9998
# Epoch 101: val_accuracy did not improve from 0.95312
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0226 - accuracy: 0.9998 - val_loss: 0.1484 - val_accuracy: 0.9512 - lr: 6.4000e-04
# Epoch 102/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9998
# Epoch 102: val_accuracy improved from 0.95312 to 0.95410, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0229 - accuracy: 0.9998 - val_loss: 0.1475 - val_accuracy: 0.9541 - lr: 6.4000e-04
# Epoch 103/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.0000
# Epoch 103: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9512 - lr: 6.4000e-04
# Epoch 104/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.0000
# Epoch 104: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9512 - lr: 6.4000e-04
# Epoch 105/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 1.0000
# Epoch 105: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9502 - lr: 6.4000e-04
# Epoch 106/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9995
# Epoch 106: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0219 - accuracy: 0.9995 - val_loss: 0.1624 - val_accuracy: 0.9531 - lr: 6.4000e-04
# Epoch 107/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 1.0000
# Epoch 107: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9502 - lr: 6.4000e-04
# Epoch 108/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 1.0000
# Epoch 108: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9512 - lr: 6.4000e-04
# Epoch 109/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.0000
# Epoch 109: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9512 - lr: 6.4000e-04
# Epoch 110/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0215 - accuracy: 1.0000
# Epoch 110: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9531 - lr: 6.4000e-04
# Epoch 111/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 0.9993
# Epoch 111: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0221 - accuracy: 0.9993 - val_loss: 0.1607 - val_accuracy: 0.9521 - lr: 6.4000e-04
# Epoch 112/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 1.0000
# Epoch 112: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9541 - lr: 6.4000e-04
# Epoch 113/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 113: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9541 - lr: 5.1200e-04
# Epoch 114/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 1.0000
# Epoch 114: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9541 - lr: 5.1200e-04
# Epoch 115/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9998
# Epoch 115: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0199 - accuracy: 0.9998 - val_loss: 0.1506 - val_accuracy: 0.9502 - lr: 5.1200e-04
# Epoch 116/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 1.0000
# Epoch 116: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9521 - lr: 5.1200e-04
# Epoch 117/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9998
# Epoch 117: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0194 - accuracy: 0.9998 - val_loss: 0.1416 - val_accuracy: 0.9541 - lr: 5.1200e-04
# Epoch 118/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0186 - accuracy: 1.0000
# Epoch 118: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9531 - lr: 5.1200e-04
# Epoch 119/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 1.0000
# Epoch 119: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9531 - lr: 5.1200e-04
# Epoch 120/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0193 - accuracy: 1.0000
# Epoch 120: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9512 - lr: 5.1200e-04
# Epoch 121/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 1.0000
# Epoch 121: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9541 - lr: 5.1200e-04
# Epoch 122/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 122: val_accuracy did not improve from 0.95410
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9502 - lr: 5.1200e-04
# Epoch 123/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 123: val_accuracy improved from 0.95410 to 0.95508, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9551 - lr: 4.0960e-04
# Epoch 124/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 124: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9531 - lr: 4.0960e-04
# Epoch 125/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 125: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9531 - lr: 4.0960e-04
# Epoch 126/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 1.0000
# Epoch 126: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9531 - lr: 4.0960e-04
# Epoch 127/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 127: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 48ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9521 - lr: 4.0960e-04
# Epoch 128/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 1.0000
# Epoch 128: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9541 - lr: 4.0960e-04
# Epoch 129/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 129: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9521 - lr: 4.0960e-04
# Epoch 130/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 130: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9531 - lr: 4.0960e-04
# Epoch 131/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000
# Epoch 131: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9531 - lr: 4.0960e-04
# Epoch 132/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000
# Epoch 132: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9531 - lr: 4.0960e-04
# Epoch 133/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 1.0000
# Epoch 133: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9512 - lr: 4.0960e-04
# Epoch 134/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 0.9998
# Epoch 134: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0171 - accuracy: 0.9998 - val_loss: 0.1481 - val_accuracy: 0.9521 - lr: 3.2768e-04
# Epoch 135/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 1.0000
# Epoch 135: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9521 - lr: 3.2768e-04
# Epoch 136/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000
# Epoch 136: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9492 - lr: 3.2768e-04
# Epoch 137/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 137: val_accuracy did not improve from 0.95508
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9541 - lr: 3.2768e-04
# Epoch 138/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 1.0000
# Epoch 138: val_accuracy improved from 0.95508 to 0.95703, saving model to /kaggle/working/alzheimers_combined_model.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9570 - lr: 3.2768e-04
# Epoch 139/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 139: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9531 - lr: 3.2768e-04
# Epoch 140/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 140: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9521 - lr: 3.2768e-04
# Epoch 141/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 1.0000
# Epoch 141: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9502 - lr: 3.2768e-04
# Epoch 142/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 142: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9541 - lr: 3.2768e-04
# Epoch 143/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 143: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9531 - lr: 3.2768e-04
# Epoch 144/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 144: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9531 - lr: 3.2768e-04
# Epoch 145/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 145: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9502 - lr: 3.2768e-04
# Epoch 146/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 1.0000
# Epoch 146: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9531 - lr: 3.2768e-04
# Epoch 147/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 147: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9541 - lr: 3.2768e-04
# Epoch 148/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 1.0000
# Epoch 148: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9521 - lr: 3.2768e-04
# Epoch 149/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 1.0000
# Epoch 149: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9512 - lr: 2.6214e-04
# Epoch 150/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 1.0000
# Epoch 150: val_accuracy did not improve from 0.95703
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9551 - lr: 2.6214e-04

# %% [markdown]
# ## Accuracy & Validation Accuracy Curve

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Classification Report

# %%
class_names = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

from sklearn.metrics import confusion_matrix, classification_report

# Predict on validation data
y_pred = combined_model.predict(X_test)

# Convert predictions and true labels back from one-hot encoding
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

classificationReports = classification_report(y_true_classes, y_pred_classes, target_names=class_names)
print("Classification Report:")
print(classificationReports)
# Out:
# 40/40 [==============================] - 2s 33ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.94      0.89      0.91       160
# ModerateDemented       1.00      0.82      0.90        11
#      NonDemented       0.97      0.99      0.98       633
# VeryMildDemented       0.96      0.96      0.96       476
#
#         accuracy                           0.96      1280
#        macro avg       0.97      0.91      0.94      1280
#     weighted avg       0.96      0.96      0.96      1280

# %% [markdown]
# ## Accuracy

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy using accuracy_score
acc = accuracy_score(y_true_classes, y_pred_classes)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.9625

# %% [markdown]
# ## Confusion Matrix

# %%
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[142   0   7  11]
#  [  0   9   1   1]
#  [  1   0 626   6]
#  [  8   0  13 455]]

# %%
import itertools

# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Plot confusion matrix
plt.figure(figsize=(8, 6))
plot_confusion_matrix(conf_matrix, classes=class_names, normalize=False, title='Confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## Accuracy-Loss Curve

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ROC-AUC

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

# Compute ROC curve and ROC area for each class
n_classes = len(class_names)
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[class_names[i]] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc['micro-average'] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{class_names[i]} (AUC = {roc_auc[class_names[i]]:.2f})')

plt.plot(fpr["micro"], tpr["micro"], label='micro-average (AUC = {0:0.2f})'.format(roc_auc['micro-average']), linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Display AUC-ROC values
for class_name, auc_value in roc_auc.items():
    print(f'AUC-ROC ({class_name}): {auc_value:.4f}')
# Out:
# AUC-ROC (MildDemented): 0.9922
# AUC-ROC (ModerateDemented): 1.0000
# AUC-ROC (NonDemented): 0.9976
# AUC-ROC (VeryMildDemented): 0.9946
# AUC-ROC (micro-average): 0.9972

# %% [markdown]
# ## Recall, Precision, F1-score

# %%
# Calculate True Positives, False Positives, False Negatives for each class
tp = np.diag(conf_matrix)
fp = np.sum(conf_matrix, axis=0) - tp
fn = np.sum(conf_matrix, axis=1) - tp
# Calculate True Negatives (TN) for each class
tn = []
for i in range(len(conf_matrix)):
    temp = np.delete(conf_matrix, i, 0)  # Remove ith row
    temp = np.delete(temp, i, 1)  # Remove ith column
    tn.append(np.sum(temp))

# Calculate Recall, Precision, and F1-score for each class
recall = tp / (tp + fn)
precision = np.where((tp + fp) == 0, 0, tp / (tp + fp))  # Set precision to 0 where TP + FP == 0
precision[np.isnan(precision)] = 0  # Handle NaN resulting from divisions by zero
f1_score = 2 * (precision * recall) / (precision + recall)
f1_score[np.isnan(f1_score)] = 0  # Handle NaN resulting from divisions by zero

# Calculate average Recall, Precision, and F1-score
macro_avg_recall = np.mean(recall)
macro_avg_precision = np.mean(precision)
macro_avg_f1_score = np.mean(f1_score)

print(f"Macro-average Recall: {macro_avg_recall:.4f}")
print(f"Macro-average Precision: {macro_avg_precision:.4f}")
print(f"Macro-average F1-score: {macro_avg_f1_score:.4f}")
# Out:
# Macro-average Recall: 0.9126
# Macro-average Precision: 0.9675
# Macro-average F1-score: 0.9376

# %% [markdown]
# ## G-mean score & Specificity

# %%
# Calculate True Negatives for each class
tn = np.sum(conf_matrix) - (fp + fn + tp)

# Calculate Sensitivity (Recall) for each class
sensitivity = tp / (tp + fn)

# Calculate Specificity for each class
specificity = tn / (tn + fp)

# Calculate G-Mean for each class
g_mean = np.sqrt(sensitivity * specificity)

# Calculate average Sensitivity, Specificity, and G-Mean
avg_specificity = np.mean(specificity)
avg_g_mean = np.mean(g_mean)

print(f"Average Specificity: {avg_specificity:.4f}")
print(f"Average G-Mean: {avg_g_mean:.4f}")
# Out:
# Average Specificity: 0.9843
# Average G-Mean: 0.9469

# %% [markdown]
# MCC

# %%
def matthews_corr_coefficient(tp, tn, fp, fn):
    numerator = (tp * tn) - (fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
    mcc = numerator / denominator if denominator != 0 else 0  # Handle division by zero
    return mcc

# Calculate MCC for each class against the rest
mcc_per_class = []
for i in range(len(tp)):
    tp_i, tn_i = tp[i], np.sum(np.delete(tp, i))  # True positives and true negatives for class i
    fp_i, fn_i = fp[i], np.sum(np.delete(fp, i))  # False positives and false negatives for class i
    
    mcc_i = matthews_corr_coefficient(tp_i, tn_i, fp_i, fn_i)
    mcc_per_class.append(mcc_i)

# Calculate average MCC across all classes
mcc_avg = np.mean(mcc_per_class)
print("Average MCC:", mcc_avg)
# Out:
# Average MCC: 0.7683834904147521
