# %% [markdown]
# <a href="https://colab.research.google.com/github/Rimon-Roy/Alzheimer-s-diseases-Ditection/blob/main/alzheimer_inceptionv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Packages

# %%
import os
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
from PIL import Image
import tensorflow as tf
import keras_cv
from tensorflow.data import AUTOTUNE
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.layers import (
    RandomBrightness, RandomZoom, RandomFlip,
    Input, Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend

# %% [markdown]
# ## Load the dataset

# %%
X_loaded = np.load('/kaggle/input/alzheimer/X_final.npy')
Y_loaded = np.load('/kaggle/input/alzheimer/Y_final.npy')

# %% [markdown]
# ## Reshape and convert to RGB

# %%
# Reshape the grayscale data to (num_samples, height, width, channels)
X_loaded_resized = np.resize(X_loaded, (len(X_loaded), 150, 150, 1))

# Replicate the single channel to create three channels
X_loaded_rgb = np.repeat(X_loaded_resized, 3, axis=-1)

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_loaded_rgb, Y_loaded, random_state=42)
X_train.shape
# Out:
# (6400, 150, 150, 3)

# %%
mean = np.mean(X_train)
std = np.std(X_train)

X_train = ((X_train - mean) / std).astype(np.float32)

# %% [markdown]
# ## Spliting the dataset into train and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train data aaugmentation

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(
featurewise_center=False,
samplewise_center=False,
featurewise_std_normalization=False,
samplewise_std_normalization=False,
zca_whitening=False,
rotation_range=10,
zoom_range=0.2,
width_shift_range=0.2,
horizontal_flip=False,
vertical_flip=False)

datagen.fit(X_train)

# %% [markdown]
# ## InceptionV3 Model

# %% [markdown]
# ### Import packages for I-V3

# %% [markdown]
# ### Load and Preprocess the pretrained model

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Flatten, BatchNormalization, Dropout, Dense, concatenate, Input
from tensorflow.keras.applications import InceptionV3
import tensorflow as tf

# Load the InceptionV3 model without the fully connected layers
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Additional layers
additional_model = Sequential()
additional_model.add(Flatten())
additional_model.add(BatchNormalization())
additional_model.add(Dropout(0.25))
additional_model.add(Dense(512, activation='relu'))
additional_model.add(BatchNormalization())
additional_model.add(Dropout(0.5))
additional_model.add(Dense(4, activation='softmax'))

# Create an input tensor for the InceptionV3 base
inception_input = Input(shape=(150, 150, 3))

# Connect the InceptionV3 base
inception_output = base_model(inception_input)

# Flatten the InceptionV3 output
inception_output_flatten = Flatten()(inception_output)

# Connect the InceptionV3 output with the output of the additional layers
combined_output = concatenate([inception_output_flatten, additional_model(inception_input)])

# Final output layer
output = Dense(4, activation='softmax')(combined_output)

# Create the combined model
model = Model(inputs=inception_input, outputs=output)

# Compile the model
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.1)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  inception_v3 (Functional)   (None, 3, 3, 2048)           2180278   ['input_2[0][0]']
#                                                           4
#
#  flatten_1 (Flatten)         (None, 18432)                0         ['inception_v3[0][0]']
#
#  sequential (Sequential)     (None, 4)                    3483461   ['input_2[0][0]']
#                                                           2
#
#  concatenate_2 (Concatenate  (None, 18436)                0         ['flatten_1[0][0]',
#  )                                                                   'sequential[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    73748     ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 56711144 (216.34 MB)
# Trainable params: 34772336 (132.65 MB)
# Non-trainable params: 21938808 (83.69 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
from keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint
import os

# Define the directory to save the model weights
save_dir = '/kaggle/working/'
model_name = 'alzheimers_InceptionV3.h5'
model_path = os.path.join(save_dir, model_name)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.8, patience=10)
tensorboard = TensorBoard(log_dir='logs')
checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', save_best_only=True, mode='auto', verbose=1)

# Fit the model
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.2, callbacks=[reduce_lr, tensorboard, checkpoint])
# Out:
# Epoch 1/150
# 127/128 [============================>.] - ETA: 0s - loss: 1.4821 - accuracy: 0.5020
# Epoch 1: val_accuracy improved from -inf to 0.54199, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 128/128 [==============================] - 16s 62ms/step - loss: 1.4782 - accuracy: 0.5024 - val_loss: 1.1612 - val_accuracy: 0.5420 - lr: 0.0010
# Epoch 2/150
# 127/128 [============================>.] - ETA: 0s - loss: 1.2724 - accuracy: 0.5664
# Epoch 2: val_accuracy did not improve from 0.54199
# 128/128 [==============================] - 5s 35ms/step - loss: 1.2749 - accuracy: 0.5654 - val_loss: 1.9356 - val_accuracy: 0.4600 - lr: 0.0010
# Epoch 3/150
# 127/128 [============================>.] - ETA: 0s - loss: 1.1262 - accuracy: 0.6122
# Epoch 3: val_accuracy improved from 0.54199 to 0.58984, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 49ms/step - loss: 1.1246 - accuracy: 0.6128 - val_loss: 1.2511 - val_accuracy: 0.5898 - lr: 0.0010
# Epoch 4/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.8241 - accuracy: 0.6750
# Epoch 4: val_accuracy improved from 0.58984 to 0.61914, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.8238 - accuracy: 0.6746 - val_loss: 0.9100 - val_accuracy: 0.6191 - lr: 0.0010
# Epoch 5/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.8121 - accuracy: 0.6882
# Epoch 5: val_accuracy improved from 0.61914 to 0.66113, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.8149 - accuracy: 0.6873 - val_loss: 0.8277 - val_accuracy: 0.6611 - lr: 0.0010
# Epoch 6/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.8534 - accuracy: 0.6941
# Epoch 6: val_accuracy did not improve from 0.66113
# 128/128 [==============================] - 4s 35ms/step - loss: 0.8518 - accuracy: 0.6941 - val_loss: 1.3219 - val_accuracy: 0.5947 - lr: 0.0010
# Epoch 7/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.8834 - accuracy: 0.6983
# Epoch 7: val_accuracy did not improve from 0.66113
# 128/128 [==============================] - 4s 35ms/step - loss: 0.8833 - accuracy: 0.6978 - val_loss: 1.2459 - val_accuracy: 0.6084 - lr: 0.0010
# Epoch 8/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5281 - accuracy: 0.7896
# Epoch 8: val_accuracy did not improve from 0.66113
# 128/128 [==============================] - 4s 35ms/step - loss: 0.5289 - accuracy: 0.7891 - val_loss: 1.0439 - val_accuracy: 0.6357 - lr: 0.0010
# Epoch 9/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.6146 - accuracy: 0.7741
# Epoch 9: val_accuracy did not improve from 0.66113
# 128/128 [==============================] - 5s 35ms/step - loss: 0.6136 - accuracy: 0.7747 - val_loss: 0.9865 - val_accuracy: 0.6484 - lr: 0.0010
# Epoch 10/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4049 - accuracy: 0.8354
# Epoch 10: val_accuracy improved from 0.66113 to 0.72070, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.4051 - accuracy: 0.8357 - val_loss: 0.7198 - val_accuracy: 0.7207 - lr: 0.0010
# Epoch 11/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4104 - accuracy: 0.8346
# Epoch 11: val_accuracy did not improve from 0.72070
# 128/128 [==============================] - 4s 35ms/step - loss: 0.4097 - accuracy: 0.8350 - val_loss: 0.7802 - val_accuracy: 0.7197 - lr: 0.0010
# Epoch 12/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.8017
# Epoch 12: val_accuracy improved from 0.72070 to 0.72461, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.5357 - accuracy: 0.8015 - val_loss: 0.8292 - val_accuracy: 0.7246 - lr: 0.0010
# Epoch 13/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3977 - accuracy: 0.8388
# Epoch 13: val_accuracy did not improve from 0.72461
# 128/128 [==============================] - 4s 35ms/step - loss: 0.3982 - accuracy: 0.8381 - val_loss: 0.9640 - val_accuracy: 0.6699 - lr: 0.0010
# Epoch 14/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3068 - accuracy: 0.8777
# Epoch 14: val_accuracy did not improve from 0.72461
# 128/128 [==============================] - 4s 35ms/step - loss: 0.3069 - accuracy: 0.8779 - val_loss: 0.8939 - val_accuracy: 0.6836 - lr: 0.0010
# Epoch 15/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3415 - accuracy: 0.8625
# Epoch 15: val_accuracy did not improve from 0.72461
# 128/128 [==============================] - 4s 35ms/step - loss: 0.3406 - accuracy: 0.8630 - val_loss: 0.8458 - val_accuracy: 0.7197 - lr: 0.0010
# Epoch 16/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3181 - accuracy: 0.8693
# Epoch 16: val_accuracy did not improve from 0.72461
# 128/128 [==============================] - 5s 35ms/step - loss: 0.3206 - accuracy: 0.8689 - val_loss: 1.6246 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 17/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3732 - accuracy: 0.8519
# Epoch 17: val_accuracy improved from 0.72461 to 0.73047, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 47ms/step - loss: 0.3725 - accuracy: 0.8518 - val_loss: 0.7524 - val_accuracy: 0.7305 - lr: 0.0010
# Epoch 18/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2545 - accuracy: 0.8996
# Epoch 18: val_accuracy did not improve from 0.73047
# 128/128 [==============================] - 5s 35ms/step - loss: 0.2554 - accuracy: 0.8992 - val_loss: 1.5084 - val_accuracy: 0.6162 - lr: 0.0010
# Epoch 19/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.8814
# Epoch 19: val_accuracy improved from 0.73047 to 0.77344, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 47ms/step - loss: 0.2972 - accuracy: 0.8818 - val_loss: 0.6520 - val_accuracy: 0.7734 - lr: 0.0010
# Epoch 20/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2015 - accuracy: 0.9235
# Epoch 20: val_accuracy improved from 0.77344 to 0.78320, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.2018 - accuracy: 0.9231 - val_loss: 0.6774 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 21/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2230 - accuracy: 0.9151
# Epoch 21: val_accuracy did not improve from 0.78320
# 128/128 [==============================] - 5s 35ms/step - loss: 0.2222 - accuracy: 0.9155 - val_loss: 0.7737 - val_accuracy: 0.7354 - lr: 0.0010
# Epoch 22/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2579 - accuracy: 0.9028
# Epoch 22: val_accuracy did not improve from 0.78320
# 128/128 [==============================] - 5s 36ms/step - loss: 0.2567 - accuracy: 0.9033 - val_loss: 0.6520 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 23/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1478 - accuracy: 0.9483
# Epoch 23: val_accuracy improved from 0.78320 to 0.79590, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 50ms/step - loss: 0.1470 - accuracy: 0.9487 - val_loss: 0.6130 - val_accuracy: 0.7959 - lr: 0.0010
# Epoch 24/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2442 - accuracy: 0.9058
# Epoch 24: val_accuracy did not improve from 0.79590
# 128/128 [==============================] - 4s 35ms/step - loss: 0.2430 - accuracy: 0.9065 - val_loss: 0.7798 - val_accuracy: 0.7432 - lr: 0.0010
# Epoch 25/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1742 - accuracy: 0.9341
# Epoch 25: val_accuracy did not improve from 0.79590
# 128/128 [==============================] - 5s 35ms/step - loss: 0.1774 - accuracy: 0.9333 - val_loss: 0.9414 - val_accuracy: 0.7139 - lr: 0.0010
# Epoch 26/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1601 - accuracy: 0.9444
# Epoch 26: val_accuracy improved from 0.79590 to 0.79980, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 47ms/step - loss: 0.1599 - accuracy: 0.9443 - val_loss: 0.5791 - val_accuracy: 0.7998 - lr: 0.0010
# Epoch 27/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0957 - accuracy: 0.9783
# Epoch 27: val_accuracy improved from 0.79980 to 0.80273, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 47ms/step - loss: 0.0963 - accuracy: 0.9780 - val_loss: 0.5765 - val_accuracy: 0.8027 - lr: 0.0010
# Epoch 28/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1742 - accuracy: 0.9345
# Epoch 28: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 5s 35ms/step - loss: 0.1753 - accuracy: 0.9343 - val_loss: 0.5960 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 29/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9471
# Epoch 29: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 4s 35ms/step - loss: 0.1382 - accuracy: 0.9460 - val_loss: 0.6869 - val_accuracy: 0.7705 - lr: 0.0010
# Epoch 30/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0891 - accuracy: 0.9788
# Epoch 30: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0890 - accuracy: 0.9790 - val_loss: 0.7345 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 31/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3015 - accuracy: 0.8890
# Epoch 31: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 4s 35ms/step - loss: 0.3035 - accuracy: 0.8884 - val_loss: 0.8550 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 32/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2384 - accuracy: 0.9090
# Epoch 32: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 4s 35ms/step - loss: 0.2390 - accuracy: 0.9087 - val_loss: 0.6767 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 33/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0892 - accuracy: 0.9744
# Epoch 33: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0890 - accuracy: 0.9744 - val_loss: 0.6055 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 34/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0900 - accuracy: 0.9756
# Epoch 34: val_accuracy did not improve from 0.80273
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0903 - accuracy: 0.9756 - val_loss: 0.8654 - val_accuracy: 0.7246 - lr: 0.0010
# Epoch 35/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9562
# Epoch 35: val_accuracy improved from 0.80273 to 0.80957, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.1172 - accuracy: 0.9561 - val_loss: 0.6250 - val_accuracy: 0.8096 - lr: 0.0010
# Epoch 36/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.9550
# Epoch 36: val_accuracy did not improve from 0.80957
# 128/128 [==============================] - 4s 35ms/step - loss: 0.1137 - accuracy: 0.9553 - val_loss: 0.6037 - val_accuracy: 0.8066 - lr: 0.0010
# Epoch 37/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9572
# Epoch 37: val_accuracy improved from 0.80957 to 0.81055, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.1178 - accuracy: 0.9575 - val_loss: 0.6275 - val_accuracy: 0.8105 - lr: 0.0010
# Epoch 38/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1512 - accuracy: 0.9498
# Epoch 38: val_accuracy did not improve from 0.81055
# 128/128 [==============================] - 4s 35ms/step - loss: 0.1506 - accuracy: 0.9500 - val_loss: 0.6245 - val_accuracy: 0.8105 - lr: 0.0010
# Epoch 39/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9897
# Epoch 39: val_accuracy did not improve from 0.81055
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0569 - accuracy: 0.9897 - val_loss: 0.9312 - val_accuracy: 0.7324 - lr: 0.0010
# Epoch 40/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9675
# Epoch 40: val_accuracy did not improve from 0.81055
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0884 - accuracy: 0.9678 - val_loss: 0.6239 - val_accuracy: 0.7959 - lr: 0.0010
# Epoch 41/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1106 - accuracy: 0.9592
# Epoch 41: val_accuracy did not improve from 0.81055
# 128/128 [==============================] - 5s 35ms/step - loss: 0.1111 - accuracy: 0.9590 - val_loss: 0.8895 - val_accuracy: 0.7422 - lr: 0.0010
# Epoch 42/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9724
# Epoch 42: val_accuracy improved from 0.81055 to 0.82812, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 47ms/step - loss: 0.0820 - accuracy: 0.9727 - val_loss: 0.5681 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 43/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0405 - accuracy: 0.9961
# Epoch 43: val_accuracy did not improve from 0.82812
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0407 - accuracy: 0.9958 - val_loss: 0.5891 - val_accuracy: 0.8135 - lr: 0.0010
# Epoch 44/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9906
# Epoch 44: val_accuracy did not improve from 0.82812
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0470 - accuracy: 0.9902 - val_loss: 1.4020 - val_accuracy: 0.6543 - lr: 0.0010
# Epoch 45/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1025 - accuracy: 0.9707
# Epoch 45: val_accuracy did not improve from 0.82812
# 128/128 [==============================] - 4s 35ms/step - loss: 0.1019 - accuracy: 0.9709 - val_loss: 0.5758 - val_accuracy: 0.8213 - lr: 0.0010
# Epoch 46/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9995
# Epoch 46: val_accuracy improved from 0.82812 to 0.83301, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 47ms/step - loss: 0.0262 - accuracy: 0.9995 - val_loss: 0.5272 - val_accuracy: 0.8330 - lr: 0.0010
# Epoch 47/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9998
# Epoch 47: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0218 - accuracy: 0.9998 - val_loss: 0.5288 - val_accuracy: 0.8330 - lr: 0.0010
# Epoch 48/150
# 128/128 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9998
# Epoch 48: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0225 - accuracy: 0.9998 - val_loss: 0.6105 - val_accuracy: 0.8086 - lr: 0.0010
# Epoch 49/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9998
# Epoch 49: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0262 - accuracy: 0.9998 - val_loss: 0.5802 - val_accuracy: 0.8291 - lr: 0.0010
# Epoch 50/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0427 - accuracy: 0.9921
# Epoch 50: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0427 - accuracy: 0.9922 - val_loss: 0.5783 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 51/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.5362 - val_accuracy: 0.8301 - lr: 0.0010
# Epoch 52/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 0.9978
# Epoch 52: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0294 - accuracy: 0.9978 - val_loss: 0.9880 - val_accuracy: 0.7549 - lr: 0.0010
# Epoch 53/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9712
# Epoch 53: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0935 - accuracy: 0.9714 - val_loss: 0.5544 - val_accuracy: 0.8262 - lr: 0.0010
# Epoch 54/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9995
# Epoch 54: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0243 - accuracy: 0.9995 - val_loss: 0.5486 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 55/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.5413 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 56/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 0.9993
# Epoch 56: val_accuracy did not improve from 0.83301
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0249 - accuracy: 0.9993 - val_loss: 0.5555 - val_accuracy: 0.8232 - lr: 0.0010
# Epoch 57/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 57: val_accuracy improved from 0.83301 to 0.83887, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.5424 - val_accuracy: 0.8389 - lr: 8.0000e-04
# Epoch 58/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.5298 - val_accuracy: 0.8369 - lr: 8.0000e-04
# Epoch 59/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.5313 - val_accuracy: 0.8369 - lr: 8.0000e-04
# Epoch 60/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.8379 - lr: 8.0000e-04
# Epoch 61/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5227 - val_accuracy: 0.8340 - lr: 8.0000e-04
# Epoch 62/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0158 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8301 - lr: 8.0000e-04
# Epoch 63/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.5235 - val_accuracy: 0.8389 - lr: 8.0000e-04
# Epoch 64/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.83887
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.8389 - lr: 8.0000e-04
# Epoch 65/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 65: val_accuracy improved from 0.83887 to 0.84277, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.5281 - val_accuracy: 0.8428 - lr: 8.0000e-04
# Epoch 66/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.5897 - val_accuracy: 0.8154 - lr: 8.0000e-04
# Epoch 67/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.5297 - val_accuracy: 0.8340 - lr: 8.0000e-04
# Epoch 68/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.8428 - lr: 8.0000e-04
# Epoch 69/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.5406 - val_accuracy: 0.8369 - lr: 8.0000e-04
# Epoch 70/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8340 - lr: 8.0000e-04
# Epoch 71/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 71: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.8350 - lr: 8.0000e-04
# Epoch 72/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.5281 - val_accuracy: 0.8369 - lr: 8.0000e-04
# Epoch 73/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.5206 - val_accuracy: 0.8418 - lr: 8.0000e-04
# Epoch 74/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.5201 - val_accuracy: 0.8369 - lr: 8.0000e-04
# Epoch 75/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.5227 - val_accuracy: 0.8379 - lr: 8.0000e-04
# Epoch 76/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 76: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.5482 - val_accuracy: 0.8301 - lr: 6.4000e-04
# Epoch 77/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.5221 - val_accuracy: 0.8359 - lr: 6.4000e-04
# Epoch 78/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 78: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.5330 - val_accuracy: 0.8350 - lr: 6.4000e-04
# Epoch 79/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 79: val_accuracy did not improve from 0.84277
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.5171 - val_accuracy: 0.8398 - lr: 6.4000e-04
# Epoch 80/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 80: val_accuracy improved from 0.84277 to 0.84766, saving model to /kaggle/working/alzheimers_InceptionV3.h5
# 128/128 [==============================] - 6s 48ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8477 - lr: 6.4000e-04
# Epoch 81/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.8398 - lr: 6.4000e-04
# Epoch 82/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 82: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.5245 - val_accuracy: 0.8389 - lr: 6.4000e-04
# Epoch 83/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 83: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.8408 - lr: 6.4000e-04
# Epoch 84/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5189 - val_accuracy: 0.8379 - lr: 6.4000e-04
# Epoch 85/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.5455 - val_accuracy: 0.8320 - lr: 6.4000e-04
# Epoch 86/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.8428 - lr: 6.4000e-04
# Epoch 87/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8379 - lr: 6.4000e-04
# Epoch 88/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 88: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.5205 - val_accuracy: 0.8359 - lr: 6.4000e-04
# Epoch 89/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.5212 - val_accuracy: 0.8408 - lr: 6.4000e-04
# Epoch 90/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.5318 - val_accuracy: 0.8379 - lr: 6.4000e-04
# Epoch 91/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5215 - val_accuracy: 0.8389 - lr: 5.1200e-04
# Epoch 92/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.8438 - lr: 5.1200e-04
# Epoch 93/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8408 - lr: 5.1200e-04
# Epoch 94/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8428 - lr: 5.1200e-04
# Epoch 95/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.8438 - lr: 5.1200e-04
# Epoch 96/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.8418 - lr: 5.1200e-04
# Epoch 97/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.5194 - val_accuracy: 0.8428 - lr: 5.1200e-04
# Epoch 98/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 98: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.8457 - lr: 5.1200e-04
# Epoch 99/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.8467 - lr: 5.1200e-04
# Epoch 100/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.8379 - lr: 5.1200e-04
# Epoch 101/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 101: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5376 - val_accuracy: 0.8369 - lr: 4.0960e-04
# Epoch 102/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 102: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.8428 - lr: 4.0960e-04
# Epoch 103/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 103: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.5412 - val_accuracy: 0.8359 - lr: 4.0960e-04
# Epoch 104/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 104: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8447 - lr: 4.0960e-04
# Epoch 105/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 105: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.8457 - lr: 4.0960e-04
# Epoch 106/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 106: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.8418 - lr: 4.0960e-04
# Epoch 107/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 107: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.8447 - lr: 4.0960e-04
# Epoch 108/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 108: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.8418 - lr: 4.0960e-04
# Epoch 109/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 109: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.8398 - lr: 4.0960e-04
# Epoch 110/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 110: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8457 - lr: 4.0960e-04
# Epoch 111/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 111: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5201 - val_accuracy: 0.8428 - lr: 3.2768e-04
# Epoch 112/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 112: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5208 - val_accuracy: 0.8398 - lr: 3.2768e-04
# Epoch 113/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 113: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.8408 - lr: 3.2768e-04
# Epoch 114/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 114: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5145 - val_accuracy: 0.8418 - lr: 3.2768e-04
# Epoch 115/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 1.0000
# Epoch 115: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5300 - val_accuracy: 0.8398 - lr: 3.2768e-04
# Epoch 116/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 116: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.8408 - lr: 3.2768e-04
# Epoch 117/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 117: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.8408 - lr: 3.2768e-04
# Epoch 118/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 118: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.8408 - lr: 3.2768e-04
# Epoch 119/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 119: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5259 - val_accuracy: 0.8438 - lr: 3.2768e-04
# Epoch 120/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 120: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8438 - lr: 3.2768e-04
# Epoch 121/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 121: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.8408 - lr: 2.6214e-04
# Epoch 122/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 122: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8447 - lr: 2.6214e-04
# Epoch 123/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 123: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.8428 - lr: 2.6214e-04
# Epoch 124/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 124: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5207 - val_accuracy: 0.8398 - lr: 2.6214e-04
# Epoch 125/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 125: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.8369 - lr: 2.6214e-04
# Epoch 126/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 126: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5198 - val_accuracy: 0.8428 - lr: 2.6214e-04
# Epoch 127/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 127: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8418 - lr: 2.6214e-04
# Epoch 128/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 128: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8428 - lr: 2.6214e-04
# Epoch 129/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 129: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.8408 - lr: 2.6214e-04
# Epoch 130/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 130: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5219 - val_accuracy: 0.8398 - lr: 2.6214e-04
# Epoch 131/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 131: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.8438 - lr: 2.0972e-04
# Epoch 132/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 132: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.8438 - lr: 2.0972e-04
# Epoch 133/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 133: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5143 - val_accuracy: 0.8418 - lr: 2.0972e-04
# Epoch 134/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 134: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5241 - val_accuracy: 0.8398 - lr: 2.0972e-04
# Epoch 135/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 135: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5228 - val_accuracy: 0.8418 - lr: 2.0972e-04
# Epoch 136/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 136: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5154 - val_accuracy: 0.8438 - lr: 2.0972e-04
# Epoch 137/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 137: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5160 - val_accuracy: 0.8428 - lr: 2.0972e-04
# Epoch 138/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 138: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8457 - lr: 2.0972e-04
# Epoch 139/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 139: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8408 - lr: 2.0972e-04
# Epoch 140/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 140: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5225 - val_accuracy: 0.8447 - lr: 2.0972e-04
# Epoch 141/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 141: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5198 - val_accuracy: 0.8438 - lr: 1.6777e-04
# Epoch 142/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 142: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8428 - lr: 1.6777e-04
# Epoch 143/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 143: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8389 - lr: 1.6777e-04
# Epoch 144/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 144: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8428 - lr: 1.6777e-04
# Epoch 145/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 145: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.8418 - lr: 1.6777e-04
# Epoch 146/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 146: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.8438 - lr: 1.6777e-04
# Epoch 147/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 147: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5202 - val_accuracy: 0.8447 - lr: 1.6777e-04
# Epoch 148/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 148: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.8457 - lr: 1.6777e-04
# Epoch 149/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 149: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.8438 - lr: 1.6777e-04
# Epoch 150/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 150: val_accuracy did not improve from 0.84766
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8438 - lr: 1.6777e-04

# %% [markdown]
# ### Accuracy vs Validation Accuracy Curve

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Classification Report

# %%
class_names = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

from sklearn.metrics import confusion_matrix, classification_report

# Predict on validation data
y_pred = model.predict(X_test)

# Convert predictions and true labels back from one-hot encoding
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

classificationReports = classification_report(y_true_classes, y_pred_classes, target_names=class_names)
print("Classification Report:")
print(classificationReports)
# Out:
# 40/40 [==============================] - 2s 24ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.73      0.70      0.72       160
# ModerateDemented       0.86      0.55      0.67        11
#      NonDemented       0.85      0.89      0.87       633
# VeryMildDemented       0.84      0.80      0.82       476
#
#         accuracy                           0.83      1280
#        macro avg       0.82      0.74      0.77      1280
#     weighted avg       0.83      0.83      0.83      1280

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy using accuracy_score
acc = accuracy_score(y_true_classes, y_pred_classes)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.83203125

# %% [markdown]
# ### Confusion Matrix

# %%
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[112   0  23  25]
#  [  0   6   3   2]
#  [ 20   0 565  48]
#  [ 21   1  72 382]]

# %%
import itertools

# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Plot confusion matrix
plt.figure(figsize=(8, 6))
plot_confusion_matrix(conf_matrix, classes=class_names, normalize=False, title='Confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ### Model Accuracy and Loss Curve

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ROC-AUC

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

# Compute ROC curve and ROC area for each class
n_classes = len(class_names)
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[class_names[i]] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc['micro-average'] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{class_names[i]} (AUC = {roc_auc[class_names[i]]:.2f})')

plt.plot(fpr["micro"], tpr["micro"], label='micro-average (AUC = {0:0.2f})'.format(roc_auc['micro-average']), linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Display AUC-ROC values
for class_name, auc_value in roc_auc.items():
    print(f'AUC-ROC ({class_name}): {auc_value:.4f}')
# Out:
# AUC-ROC (MildDemented): 0.9618
# AUC-ROC (ModerateDemented): 0.9994
# AUC-ROC (NonDemented): 0.9426
# AUC-ROC (VeryMildDemented): 0.9299
# AUC-ROC (micro-average): 0.9666

# %% [markdown]
# ### Recall, Precision and F-1 Score

# %%
# Calculate True Positives, False Positives, False Negatives for each class
tp = np.diag(conf_matrix)
fp = np.sum(conf_matrix, axis=0) - tp
fn = np.sum(conf_matrix, axis=1) - tp
# Calculate True Negatives (TN) for each class
tn = []
for i in range(len(conf_matrix)):
    temp = np.delete(conf_matrix, i, 0)  # Remove ith row
    temp = np.delete(temp, i, 1)  # Remove ith column
    tn.append(np.sum(temp))

# Calculate Recall, Precision, and F1-score for each class
recall = tp / (tp + fn)
precision = np.where((tp + fp) == 0, 0, tp / (tp + fp))  # Set precision to 0 where TP + FP == 0
precision[np.isnan(precision)] = 0  # Handle NaN resulting from divisions by zero
f1_score = 2 * (precision * recall) / (precision + recall)
f1_score[np.isnan(f1_score)] = 0  # Handle NaN resulting from divisions by zero

# Calculate average Recall, Precision, and F1-score
macro_avg_recall = np.mean(recall)
macro_avg_precision = np.mean(precision)
macro_avg_f1_score = np.mean(f1_score)

print(f"Macro-average Recall: {macro_avg_recall:.4f}")
print(f"Macro-average Precision: {macro_avg_precision:.4f}")
print(f"Macro-average F1-score: {macro_avg_f1_score:.4f}")
# Out:
# Macro-average Recall: 0.7351
# Macro-average Precision: 0.8193
# Macro-average F1-score: 0.7683

# %% [markdown]
# ### Specificity and G-mean Score

# %%
# Calculate True Negatives for each class
tn = np.sum(conf_matrix) - (fp + fn + tp)

# Calculate Sensitivity (Recall) for each class
sensitivity = tp / (tp + fn)

# Calculate Specificity for each class
specificity = tn / (tn + fp)

# Calculate G-Mean for each class
g_mean = np.sqrt(sensitivity * specificity)

# Calculate average Sensitivity, Specificity, and G-Mean
avg_specificity = np.mean(specificity)
avg_g_mean = np.mean(g_mean)

print(f"Average Specificity: {avg_specificity:.4f}")
print(f"Average G-Mean: {avg_g_mean:.4f}")
# Out:
# Average Specificity: 0.9295
# Average G-Mean: 0.8207

# %% [markdown]
# ### MCC

# %%
def matthews_corr_coefficient(tp, tn, fp, fn):
    numerator = (tp * tn) - (fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
    mcc = numerator / denominator if denominator != 0 else 0  # Handle division by zero
    return mcc

# Calculate MCC for each class against the rest
mcc_per_class = []
for i in range(len(tp)):
    tp_i, tn_i = tp[i], np.sum(np.delete(tp, i))  # True positives and true negatives for class i
    fp_i, fn_i = fp[i], np.sum(np.delete(fp, i))  # False positives and false negatives for class i

    mcc_i = matthews_corr_coefficient(tp_i, tn_i, fp_i, fn_i)
    mcc_per_class.append(mcc_i)

# Calculate average MCC across all classes
mcc_avg = np.mean(mcc_per_class)
print("Average MCC:", mcc_avg)
# Out:
# Average MCC: 0.47430720434624135
