# %% [markdown]
# <a href="https://colab.research.google.com/github/Rimon-Roy/Alzheimer-s-diseases-Ditection/blob/main/alzheimer_sdensenet121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
from PIL import Image
import tensorflow as tf
import keras_cv
from tensorflow.data import AUTOTUNE
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import (
    RandomBrightness, RandomZoom, RandomFlip,
    Input, Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend

# %%
X_loaded = np.load('/kaggle/input/alzheimer/X_final.npy')
Y_loaded = np.load('/kaggle/input/alzheimer/Y_final.npy')

# %%
# Reshape the grayscale data to (num_samples, height, width, channels)
X_loaded_resized = np.resize(X_loaded, (len(X_loaded), 150, 150, 1))

# Replicate the single channel to create three channels
X_loaded_rgb = np.repeat(X_loaded_resized, 3, axis=-1)

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_loaded_rgb, Y_loaded, random_state=42)
X_train.shape
# Out:
# (6400, 150, 150, 3)

# %%
mean = np.mean(X_train)
std = np.std(X_train)

X_train = ((X_train - mean) / std).astype(np.float32)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
datagen = keras.preprocessing.image.ImageDataGenerator(
featurewise_center=False,
samplewise_center=False,
featurewise_std_normalization=False,
samplewise_std_normalization=False,
zca_whitening=False,
rotation_range=10,
zoom_range=0.2,
width_shift_range=0.2,
horizontal_flip=False,
vertical_flip=False)

datagen.fit(X_train)

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Flatten, BatchNormalization, Dropout, Dense, concatenate, Input
from tensorflow.keras.applications import DenseNet121
import tensorflow as tf

# Load DenseNet121 without the fully connected layers
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Additional layers
additional_model = Sequential()
additional_model.add(Flatten())
additional_model.add(BatchNormalization())
additional_model.add(Dropout(0.25))
additional_model.add(Dense(512, activation='relu'))
additional_model.add(BatchNormalization())
additional_model.add(Dropout(0.5))
additional_model.add(Dense(4, activation='softmax'))

# Create an input tensor for the DenseNet121 base
densenet_input = Input(shape=(150, 150, 3))

# Connect the DenseNet121 base
densenet_output = base_model(densenet_input)

# Flatten the DenseNet121 output
densenet_output_flatten = Flatten()(densenet_output)

# Connect the DenseNet121 output with the output of the additional layers
combined_output = concatenate([densenet_output_flatten, additional_model(densenet_input)])

# Final output layer
output = Dense(4, activation='softmax')(combined_output)

# Create the combined model
model = Model(inputs=densenet_input, outputs=output)

# Compile the model
optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.1)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  densenet121 (Functional)    (None, 4, 4, 1024)           7037504   ['input_2[0][0]']
#
#  flatten_1 (Flatten)         (None, 16384)                0         ['densenet121[0][0]']
#
#  sequential (Sequential)     (None, 4)                    3483461   ['input_2[0][0]']
#                                                           2
#
#  concatenate (Concatenate)   (None, 16388)                0         ['flatten_1[0][0]',
#                                                                      'sequential[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    65556     ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 41937672 (159.98 MB)
# Trainable params: 34764144 (132.61 MB)
# Non-trainable params: 7173528 (27.36 MB)
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint

optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.1)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Define the directory to save the model weights
save_dir = '/kaggle/working/'
model_name = 'alzheimers_DenseNet121.h5'
model_path = os.path.join(save_dir, model_name)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.8, patience=10)
tensorboard = TensorBoard(log_dir='logs')
checkpoint = ModelCheckpoint(model_path, monitor='val_accuracy', save_best_only=True, mode='auto', verbose=1)


# Fit the model
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.2, callbacks=[reduce_lr, tensorboard, checkpoint])
# Out:
# Epoch 1/150
# 127/128 [============================>.] - ETA: 0s - loss: 1.3535 - accuracy: 0.5187
# Epoch 1: val_accuracy improved from -inf to 0.59863, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 128/128 [==============================] - 20s 77ms/step - loss: 1.3514 - accuracy: 0.5193 - val_loss: 1.0139 - val_accuracy: 0.5986 - lr: 0.0010
# Epoch 2/150
# 127/128 [============================>.] - ETA: 0s - loss: 1.0629 - accuracy: 0.5812
# Epoch 2: val_accuracy did not improve from 0.59863
# 128/128 [==============================] - 6s 44ms/step - loss: 1.0648 - accuracy: 0.5801 - val_loss: 0.9857 - val_accuracy: 0.5752 - lr: 0.0010
# Epoch 3/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.9543 - accuracy: 0.6275
# Epoch 3: val_accuracy improved from 0.59863 to 0.63379, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.9543 - accuracy: 0.6272 - val_loss: 1.3794 - val_accuracy: 0.6338 - lr: 0.0010
# Epoch 4/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.8566 - accuracy: 0.6641
# Epoch 4: val_accuracy did not improve from 0.63379
# 128/128 [==============================] - 6s 44ms/step - loss: 0.8564 - accuracy: 0.6643 - val_loss: 0.9935 - val_accuracy: 0.6104 - lr: 0.0010
# Epoch 5/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.7419 - accuracy: 0.7037
# Epoch 5: val_accuracy improved from 0.63379 to 0.69238, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.7391 - accuracy: 0.7048 - val_loss: 0.7152 - val_accuracy: 0.6924 - lr: 0.0010
# Epoch 6/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.6982 - accuracy: 0.7146
# Epoch 6: val_accuracy improved from 0.69238 to 0.72363, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.6976 - accuracy: 0.7151 - val_loss: 0.6667 - val_accuracy: 0.7236 - lr: 0.0010
# Epoch 7/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5581 - accuracy: 0.7645
# Epoch 7: val_accuracy did not improve from 0.72363
# 128/128 [==============================] - 6s 44ms/step - loss: 0.5613 - accuracy: 0.7637 - val_loss: 0.7950 - val_accuracy: 0.6924 - lr: 0.0010
# Epoch 8/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.6756 - accuracy: 0.7232
# Epoch 8: val_accuracy did not improve from 0.72363
# 128/128 [==============================] - 6s 43ms/step - loss: 0.6756 - accuracy: 0.7231 - val_loss: 1.1502 - val_accuracy: 0.6133 - lr: 0.0010
# Epoch 9/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.6065 - accuracy: 0.7633
# Epoch 9: val_accuracy did not improve from 0.72363
# 128/128 [==============================] - 6s 44ms/step - loss: 0.6057 - accuracy: 0.7642 - val_loss: 1.0671 - val_accuracy: 0.6162 - lr: 0.0010
# Epoch 10/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4611 - accuracy: 0.8056
# Epoch 10: val_accuracy did not improve from 0.72363
# 128/128 [==============================] - 6s 44ms/step - loss: 0.4645 - accuracy: 0.8044 - val_loss: 0.7457 - val_accuracy: 0.7168 - lr: 0.0010
# Epoch 11/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5276 - accuracy: 0.7874
# Epoch 11: val_accuracy did not improve from 0.72363
# 128/128 [==============================] - 6s 44ms/step - loss: 0.5271 - accuracy: 0.7878 - val_loss: 0.7611 - val_accuracy: 0.7119 - lr: 0.0010
# Epoch 12/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4892 - accuracy: 0.8031
# Epoch 12: val_accuracy improved from 0.72363 to 0.78711, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.4906 - accuracy: 0.8030 - val_loss: 0.5365 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 13/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4653 - accuracy: 0.8100
# Epoch 13: val_accuracy did not improve from 0.78711
# 128/128 [==============================] - 6s 46ms/step - loss: 0.4655 - accuracy: 0.8096 - val_loss: 0.5513 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 14/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3726 - accuracy: 0.8474
# Epoch 14: val_accuracy did not improve from 0.78711
# 128/128 [==============================] - 6s 44ms/step - loss: 0.3713 - accuracy: 0.8481 - val_loss: 0.5219 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 15/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3759 - accuracy: 0.8541
# Epoch 15: val_accuracy did not improve from 0.78711
# 128/128 [==============================] - 6s 44ms/step - loss: 0.3810 - accuracy: 0.8523 - val_loss: 0.5852 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 16/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.7899
# Epoch 16: val_accuracy did not improve from 0.78711
# 128/128 [==============================] - 6s 44ms/step - loss: 0.5363 - accuracy: 0.7910 - val_loss: 0.9752 - val_accuracy: 0.6582 - lr: 0.0010
# Epoch 17/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.5581 - accuracy: 0.7936
# Epoch 17: val_accuracy improved from 0.78711 to 0.79492, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 56ms/step - loss: 0.5550 - accuracy: 0.7947 - val_loss: 0.5241 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 18/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3367 - accuracy: 0.8713
# Epoch 18: val_accuracy improved from 0.79492 to 0.81836, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.3363 - accuracy: 0.8718 - val_loss: 0.4571 - val_accuracy: 0.8184 - lr: 0.0010
# Epoch 19/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.3125 - accuracy: 0.8725
# Epoch 19: val_accuracy did not improve from 0.81836
# 128/128 [==============================] - 6s 44ms/step - loss: 0.3114 - accuracy: 0.8730 - val_loss: 0.6704 - val_accuracy: 0.7490 - lr: 0.0010
# Epoch 20/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2508 - accuracy: 0.9045
# Epoch 20: val_accuracy did not improve from 0.81836
# 128/128 [==============================] - 6s 44ms/step - loss: 0.2514 - accuracy: 0.9048 - val_loss: 0.4452 - val_accuracy: 0.8135 - lr: 0.0010
# Epoch 21/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2946 - accuracy: 0.8812
# Epoch 21: val_accuracy did not improve from 0.81836
# 128/128 [==============================] - 6s 44ms/step - loss: 0.2955 - accuracy: 0.8806 - val_loss: 0.5579 - val_accuracy: 0.7920 - lr: 0.0010
# Epoch 22/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.4143 - accuracy: 0.8548
# Epoch 22: val_accuracy did not improve from 0.81836
# 128/128 [==============================] - 6s 43ms/step - loss: 0.4162 - accuracy: 0.8533 - val_loss: 0.4516 - val_accuracy: 0.8135 - lr: 0.0010
# Epoch 23/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2208 - accuracy: 0.9186
# Epoch 23: val_accuracy improved from 0.81836 to 0.83008, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.2216 - accuracy: 0.9182 - val_loss: 0.4559 - val_accuracy: 0.8301 - lr: 0.0010
# Epoch 24/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2111 - accuracy: 0.9220
# Epoch 24: val_accuracy improved from 0.83008 to 0.84082, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.2110 - accuracy: 0.9221 - val_loss: 0.4199 - val_accuracy: 0.8408 - lr: 0.0010
# Epoch 25/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1814 - accuracy: 0.9373
# Epoch 25: val_accuracy did not improve from 0.84082
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1824 - accuracy: 0.9365 - val_loss: 0.5424 - val_accuracy: 0.7939 - lr: 0.0010
# Epoch 26/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2303 - accuracy: 0.9126
# Epoch 26: val_accuracy improved from 0.84082 to 0.84180, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.2326 - accuracy: 0.9114 - val_loss: 0.4029 - val_accuracy: 0.8418 - lr: 0.0010
# Epoch 27/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1929 - accuracy: 0.9294
# Epoch 27: val_accuracy did not improve from 0.84180
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1922 - accuracy: 0.9299 - val_loss: 0.6193 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 28/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1792 - accuracy: 0.9370
# Epoch 28: val_accuracy did not improve from 0.84180
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1790 - accuracy: 0.9370 - val_loss: 0.5056 - val_accuracy: 0.8027 - lr: 0.0010
# Epoch 29/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1591 - accuracy: 0.9464
# Epoch 29: val_accuracy improved from 0.84180 to 0.84961, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 8s 59ms/step - loss: 0.1602 - accuracy: 0.9453 - val_loss: 0.3968 - val_accuracy: 0.8496 - lr: 0.0010
# Epoch 30/150
# 128/128 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9502
# Epoch 30: val_accuracy did not improve from 0.84961
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1513 - accuracy: 0.9502 - val_loss: 0.5598 - val_accuracy: 0.7852 - lr: 0.0010
# Epoch 31/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1636 - accuracy: 0.9414
# Epoch 31: val_accuracy did not improve from 0.84961
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1630 - accuracy: 0.9419 - val_loss: 0.4377 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 32/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1874 - accuracy: 0.9291
# Epoch 32: val_accuracy did not improve from 0.84961
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1872 - accuracy: 0.9294 - val_loss: 0.5363 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 33/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1513 - accuracy: 0.9503
# Epoch 33: val_accuracy improved from 0.84961 to 0.87207, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 8s 60ms/step - loss: 0.1507 - accuracy: 0.9507 - val_loss: 0.3726 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 34/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1524 - accuracy: 0.9471
# Epoch 34: val_accuracy did not improve from 0.87207
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1521 - accuracy: 0.9473 - val_loss: 0.4154 - val_accuracy: 0.8379 - lr: 0.0010
# Epoch 35/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1526 - accuracy: 0.9437
# Epoch 35: val_accuracy did not improve from 0.87207
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1530 - accuracy: 0.9434 - val_loss: 0.5742 - val_accuracy: 0.7920 - lr: 0.0010
# Epoch 36/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9606
# Epoch 36: val_accuracy did not improve from 0.87207
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1204 - accuracy: 0.9604 - val_loss: 0.4763 - val_accuracy: 0.8340 - lr: 0.0010
# Epoch 37/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1183 - accuracy: 0.9624
# Epoch 37: val_accuracy did not improve from 0.87207
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1183 - accuracy: 0.9624 - val_loss: 0.3648 - val_accuracy: 0.8584 - lr: 0.0010
# Epoch 38/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1189 - accuracy: 0.9601
# Epoch 38: val_accuracy did not improve from 0.87207
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1184 - accuracy: 0.9604 - val_loss: 0.4068 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 39/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9619
# Epoch 39: val_accuracy did not improve from 0.87207
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1185 - accuracy: 0.9612 - val_loss: 0.3905 - val_accuracy: 0.8643 - lr: 0.0010
# Epoch 40/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.9626
# Epoch 40: val_accuracy improved from 0.87207 to 0.87305, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.1191 - accuracy: 0.9597 - val_loss: 0.3541 - val_accuracy: 0.8730 - lr: 0.0010
# Epoch 41/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.2614 - accuracy: 0.9023
# Epoch 41: val_accuracy did not improve from 0.87305
# 128/128 [==============================] - 6s 45ms/step - loss: 0.2598 - accuracy: 0.9031 - val_loss: 0.5646 - val_accuracy: 0.8057 - lr: 0.0010
# Epoch 42/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9567
# Epoch 42: val_accuracy improved from 0.87305 to 0.88086, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.1174 - accuracy: 0.9570 - val_loss: 0.3403 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 43/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9719
# Epoch 43: val_accuracy did not improve from 0.88086
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1022 - accuracy: 0.9719 - val_loss: 0.3906 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 44/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9562
# Epoch 44: val_accuracy did not improve from 0.88086
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1222 - accuracy: 0.9558 - val_loss: 0.9318 - val_accuracy: 0.7197 - lr: 0.0010
# Epoch 45/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9638
# Epoch 45: val_accuracy improved from 0.88086 to 0.89453, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.1054 - accuracy: 0.9639 - val_loss: 0.3089 - val_accuracy: 0.8945 - lr: 0.0010
# Epoch 46/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9675
# Epoch 46: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0978 - accuracy: 0.9673 - val_loss: 0.4613 - val_accuracy: 0.8262 - lr: 0.0010
# Epoch 47/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9727
# Epoch 47: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0925 - accuracy: 0.9729 - val_loss: 0.4013 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 48/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9828
# Epoch 48: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0697 - accuracy: 0.9829 - val_loss: 0.4745 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 49/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1782 - accuracy: 0.9316
# Epoch 49: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1775 - accuracy: 0.9319 - val_loss: 0.4332 - val_accuracy: 0.8457 - lr: 0.0010
# Epoch 50/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0714 - accuracy: 0.9838
# Epoch 50: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0713 - accuracy: 0.9839 - val_loss: 0.2975 - val_accuracy: 0.8896 - lr: 0.0010
# Epoch 51/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9904
# Epoch 51: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0524 - accuracy: 0.9902 - val_loss: 0.3381 - val_accuracy: 0.8838 - lr: 0.0010
# Epoch 52/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9722
# Epoch 52: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0824 - accuracy: 0.9724 - val_loss: 0.3020 - val_accuracy: 0.8926 - lr: 0.0010
# Epoch 53/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9899
# Epoch 53: val_accuracy did not improve from 0.89453
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0549 - accuracy: 0.9895 - val_loss: 0.3705 - val_accuracy: 0.8740 - lr: 0.0010
# Epoch 54/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.9897
# Epoch 54: val_accuracy improved from 0.89453 to 0.90137, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0521 - accuracy: 0.9895 - val_loss: 0.2852 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 55/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9963
# Epoch 55: val_accuracy improved from 0.90137 to 0.90332, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.0412 - accuracy: 0.9961 - val_loss: 0.2911 - val_accuracy: 0.9033 - lr: 0.0010
# Epoch 56/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9675
# Epoch 56: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0976 - accuracy: 0.9673 - val_loss: 0.3460 - val_accuracy: 0.8779 - lr: 0.0010
# Epoch 57/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1203 - accuracy: 0.9545
# Epoch 57: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1200 - accuracy: 0.9548 - val_loss: 0.4704 - val_accuracy: 0.8340 - lr: 0.0010
# Epoch 58/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9966
# Epoch 58: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0334 - accuracy: 0.9966 - val_loss: 0.3074 - val_accuracy: 0.9004 - lr: 0.0010
# Epoch 59/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 0.9993
# Epoch 59: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0301 - accuracy: 0.9993 - val_loss: 0.3020 - val_accuracy: 0.8887 - lr: 0.0010
# Epoch 60/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9801
# Epoch 60: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0690 - accuracy: 0.9800 - val_loss: 0.3606 - val_accuracy: 0.8740 - lr: 0.0010
# Epoch 61/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0398 - accuracy: 0.9953
# Epoch 61: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0400 - accuracy: 0.9954 - val_loss: 0.7030 - val_accuracy: 0.7861 - lr: 0.0010
# Epoch 62/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9732
# Epoch 62: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0812 - accuracy: 0.9734 - val_loss: 0.3464 - val_accuracy: 0.8740 - lr: 0.0010
# Epoch 63/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9988
# Epoch 63: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0300 - accuracy: 0.9988 - val_loss: 0.3119 - val_accuracy: 0.9023 - lr: 0.0010
# Epoch 64/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9929
# Epoch 64: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0409 - accuracy: 0.9929 - val_loss: 0.2716 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 65/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9973
# Epoch 65: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0281 - accuracy: 0.9971 - val_loss: 0.4128 - val_accuracy: 0.8604 - lr: 0.0010
# Epoch 66/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9985
# Epoch 66: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0278 - accuracy: 0.9985 - val_loss: 0.2991 - val_accuracy: 0.8945 - lr: 8.0000e-04
# Epoch 67/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9995
# Epoch 67: val_accuracy did not improve from 0.90332
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0246 - accuracy: 0.9995 - val_loss: 0.2799 - val_accuracy: 0.9033 - lr: 8.0000e-04
# Epoch 68/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 1.0000
# Epoch 68: val_accuracy improved from 0.90332 to 0.90918, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9092 - lr: 8.0000e-04
# Epoch 69/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9995
# Epoch 69: val_accuracy did not improve from 0.90918
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0226 - accuracy: 0.9995 - val_loss: 0.2760 - val_accuracy: 0.9023 - lr: 8.0000e-04
# Epoch 70/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9998
# Epoch 70: val_accuracy did not improve from 0.90918
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0189 - accuracy: 0.9998 - val_loss: 0.2680 - val_accuracy: 0.9062 - lr: 8.0000e-04
# Epoch 71/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9995
# Epoch 71: val_accuracy did not improve from 0.90918
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0239 - accuracy: 0.9995 - val_loss: 0.2958 - val_accuracy: 0.9033 - lr: 8.0000e-04
# Epoch 72/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 0.90918
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 0.9043 - lr: 8.0000e-04
# Epoch 73/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 1.0000
# Epoch 73: val_accuracy improved from 0.90918 to 0.91113, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.2743 - val_accuracy: 0.9111 - lr: 8.0000e-04
# Epoch 74/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9998
# Epoch 74: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0203 - accuracy: 0.9998 - val_loss: 0.2959 - val_accuracy: 0.9014 - lr: 8.0000e-04
# Epoch 75/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.1241 - accuracy: 0.9631
# Epoch 75: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.1257 - accuracy: 0.9624 - val_loss: 0.8509 - val_accuracy: 0.7324 - lr: 8.0000e-04
# Epoch 76/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9966
# Epoch 76: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0316 - accuracy: 0.9966 - val_loss: 0.3140 - val_accuracy: 0.8867 - lr: 8.0000e-04
# Epoch 77/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9998
# Epoch 77: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0194 - accuracy: 0.9998 - val_loss: 0.2732 - val_accuracy: 0.9053 - lr: 8.0000e-04
# Epoch 78/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0199 - accuracy: 0.9998
# Epoch 78: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0200 - accuracy: 0.9998 - val_loss: 0.4127 - val_accuracy: 0.8535 - lr: 8.0000e-04
# Epoch 79/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9983
# Epoch 79: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0267 - accuracy: 0.9983 - val_loss: 0.2628 - val_accuracy: 0.9043 - lr: 8.0000e-04
# Epoch 80/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 1.0000
# Epoch 80: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 46ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9082 - lr: 8.0000e-04
# Epoch 81/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.3156 - val_accuracy: 0.8965 - lr: 8.0000e-04
# Epoch 82/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9998
# Epoch 82: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0187 - accuracy: 0.9998 - val_loss: 0.2678 - val_accuracy: 0.9102 - lr: 8.0000e-04
# Epoch 83/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9739
# Epoch 83: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0818 - accuracy: 0.9734 - val_loss: 0.3112 - val_accuracy: 0.9004 - lr: 8.0000e-04
# Epoch 84/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9943
# Epoch 84: val_accuracy did not improve from 0.91113
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0316 - accuracy: 0.9944 - val_loss: 0.2724 - val_accuracy: 0.9053 - lr: 6.4000e-04
# Epoch 85/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 85: val_accuracy improved from 0.91113 to 0.91309, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9131 - lr: 6.4000e-04
# Epoch 86/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9993
# Epoch 86: val_accuracy did not improve from 0.91309
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0209 - accuracy: 0.9993 - val_loss: 0.2724 - val_accuracy: 0.9111 - lr: 6.4000e-04
# Epoch 87/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.91309
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.3109 - val_accuracy: 0.8887 - lr: 6.4000e-04
# Epoch 88/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9995
# Epoch 88: val_accuracy did not improve from 0.91309
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0162 - accuracy: 0.9995 - val_loss: 0.2629 - val_accuracy: 0.9082 - lr: 6.4000e-04
# Epoch 89/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 1.0000
# Epoch 89: val_accuracy did not improve from 0.91309
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.8994 - lr: 6.4000e-04
# Epoch 90/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9998
# Epoch 90: val_accuracy did not improve from 0.91309
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0134 - accuracy: 0.9998 - val_loss: 0.2588 - val_accuracy: 0.9121 - lr: 6.4000e-04
# Epoch 91/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 91: val_accuracy improved from 0.91309 to 0.91406, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 57ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.9141 - lr: 6.4000e-04
# Epoch 92/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 92: val_accuracy did not improve from 0.91406
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9111 - lr: 6.4000e-04
# Epoch 93/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 93: val_accuracy did not improve from 0.91406
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9082 - lr: 6.4000e-04
# Epoch 94/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 94: val_accuracy did not improve from 0.91406
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.2554 - val_accuracy: 0.9121 - lr: 6.4000e-04
# Epoch 95/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 1.0000
# Epoch 95: val_accuracy improved from 0.91406 to 0.91602, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9160 - lr: 6.4000e-04
# Epoch 96/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 0.91602
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.2686 - val_accuracy: 0.9131 - lr: 6.4000e-04
# Epoch 97/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9990
# Epoch 97: val_accuracy did not improve from 0.91602
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0177 - accuracy: 0.9990 - val_loss: 0.2700 - val_accuracy: 0.9131 - lr: 6.4000e-04
# Epoch 98/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 98: val_accuracy improved from 0.91602 to 0.91699, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9170 - lr: 6.4000e-04
# Epoch 99/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 99: val_accuracy improved from 0.91699 to 0.92090, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9209 - lr: 6.4000e-04
# Epoch 100/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 100: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.3166 - val_accuracy: 0.8877 - lr: 6.4000e-04
# Epoch 101/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 101: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9180 - lr: 6.4000e-04
# Epoch 102/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 102: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.2539 - val_accuracy: 0.9111 - lr: 6.4000e-04
# Epoch 103/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9998
# Epoch 103: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0189 - accuracy: 0.9998 - val_loss: 0.2504 - val_accuracy: 0.9150 - lr: 6.4000e-04
# Epoch 104/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 104: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9111 - lr: 6.4000e-04
# Epoch 105/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 105: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2488 - val_accuracy: 0.9150 - lr: 6.4000e-04
# Epoch 106/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 106: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9141 - lr: 6.4000e-04
# Epoch 107/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9998
# Epoch 107: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0123 - accuracy: 0.9998 - val_loss: 0.2521 - val_accuracy: 0.9121 - lr: 6.4000e-04
# Epoch 108/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 108: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2615 - val_accuracy: 0.9043 - lr: 6.4000e-04
# Epoch 109/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 109: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9150 - lr: 6.4000e-04
# Epoch 110/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 110: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2504 - val_accuracy: 0.9180 - lr: 5.1200e-04
# Epoch 111/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 111: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2502 - val_accuracy: 0.9131 - lr: 5.1200e-04
# Epoch 112/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9998
# Epoch 112: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0117 - accuracy: 0.9998 - val_loss: 0.2485 - val_accuracy: 0.9111 - lr: 5.1200e-04
# Epoch 113/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 113: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9170 - lr: 5.1200e-04
# Epoch 114/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 114: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2549 - val_accuracy: 0.9072 - lr: 5.1200e-04
# Epoch 115/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 115: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.9170 - lr: 5.1200e-04
# Epoch 116/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 116: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9170 - lr: 5.1200e-04
# Epoch 117/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 117: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9111 - lr: 5.1200e-04
# Epoch 118/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
# Epoch 118: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2526 - val_accuracy: 0.9160 - lr: 5.1200e-04
# Epoch 119/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 119: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9170 - lr: 5.1200e-04
# Epoch 120/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 120: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2446 - val_accuracy: 0.9160 - lr: 4.0960e-04
# Epoch 121/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 121: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2462 - val_accuracy: 0.9180 - lr: 4.0960e-04
# Epoch 122/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 122: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2477 - val_accuracy: 0.9199 - lr: 4.0960e-04
# Epoch 123/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 123: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9160 - lr: 4.0960e-04
# Epoch 124/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 124: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9170 - lr: 4.0960e-04
# Epoch 125/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 125: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9189 - lr: 4.0960e-04
# Epoch 126/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9995
# Epoch 126: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.2477 - val_accuracy: 0.9121 - lr: 4.0960e-04
# Epoch 127/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 127: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2575 - val_accuracy: 0.9121 - lr: 4.0960e-04
# Epoch 128/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 128: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9170 - lr: 4.0960e-04
# Epoch 129/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 129: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2436 - val_accuracy: 0.9209 - lr: 4.0960e-04
# Epoch 130/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 130: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2459 - val_accuracy: 0.9189 - lr: 3.2768e-04
# Epoch 131/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 131: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9180 - lr: 3.2768e-04
# Epoch 132/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 132: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9180 - lr: 3.2768e-04
# Epoch 133/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 133: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9160 - lr: 3.2768e-04
# Epoch 134/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 134: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.9189 - lr: 3.2768e-04
# Epoch 135/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 135: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2418 - val_accuracy: 0.9170 - lr: 3.2768e-04
# Epoch 136/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 136: val_accuracy did not improve from 0.92090
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.9199 - lr: 3.2768e-04
# Epoch 137/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 137: val_accuracy improved from 0.92090 to 0.92188, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 8s 60ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9219 - lr: 3.2768e-04
# Epoch 138/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 138: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9131 - lr: 3.2768e-04
# Epoch 139/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 139: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.9170 - lr: 3.2768e-04
# Epoch 140/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 140: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9170 - lr: 3.2768e-04
# Epoch 141/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 141: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9180 - lr: 3.2768e-04
# Epoch 142/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 142: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9170 - lr: 3.2768e-04
# Epoch 143/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 143: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9180 - lr: 3.2768e-04
# Epoch 144/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 144: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.9150 - lr: 3.2768e-04
# Epoch 145/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 145: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2409 - val_accuracy: 0.9150 - lr: 3.2768e-04
# Epoch 146/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 146: val_accuracy did not improve from 0.92188
# 128/128 [==============================] - 6s 44ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9170 - lr: 3.2768e-04
# Epoch 147/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 147: val_accuracy improved from 0.92188 to 0.92383, saving model to /kaggle/working/alzheimers_DenseNet121.h5
# 128/128 [==============================] - 7s 58ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2457 - val_accuracy: 0.9238 - lr: 3.2768e-04
# Epoch 148/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 148: val_accuracy did not improve from 0.92383
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9121 - lr: 3.2768e-04
# Epoch 149/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 149: val_accuracy did not improve from 0.92383
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2400 - val_accuracy: 0.9170 - lr: 3.2768e-04
# Epoch 150/150
# 127/128 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 150: val_accuracy did not improve from 0.92383
# 128/128 [==============================] - 6s 45ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2445 - val_accuracy: 0.9189 - lr: 3.2768e-04

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
class_names = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

from sklearn.metrics import confusion_matrix, classification_report

# Predict on validation data
y_pred = model.predict(X_test)

# Convert predictions and true labels back from one-hot encoding
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

classificationReports = classification_report(y_true_classes, y_pred_classes, target_names=class_names)
print("Classification Report:")
print(classificationReports)
# Out:
# 40/40 [==============================] - 3s 31ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.92      0.87      0.89       160
# ModerateDemented       1.00      0.91      0.95        11
#      NonDemented       0.95      0.94      0.95       633
# VeryMildDemented       0.91      0.93      0.92       476
#
#         accuracy                           0.93      1280
#        macro avg       0.94      0.91      0.93      1280
#     weighted avg       0.93      0.93      0.93      1280

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy using accuracy_score
acc = accuracy_score(y_true_classes, y_pred_classes)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.93046875

# %%
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[139   0   5  16]
#  [  0  10   0   1]
#  [  6   0 598  29]
#  [  6   0  26 444]]

# %%
import itertools

# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Plot confusion matrix
plt.figure(figsize=(8, 6))
plot_confusion_matrix(conf_matrix, classes=class_names, normalize=False, title='Confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

# Compute ROC curve and ROC area for each class
n_classes = len(class_names)
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[class_names[i]] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc['micro-average'] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{class_names[i]} (AUC = {roc_auc[class_names[i]]:.2f})')

plt.plot(fpr["micro"], tpr["micro"], label='micro-average (AUC = {0:0.2f})'.format(roc_auc['micro-average']), linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Display AUC-ROC values
for class_name, auc_value in roc_auc.items():
    print(f'AUC-ROC ({class_name}): {auc_value:.4f}')
# Out:
# AUC-ROC (MildDemented): 0.9881
# AUC-ROC (ModerateDemented): 0.9999
# AUC-ROC (NonDemented): 0.9852
# AUC-ROC (VeryMildDemented): 0.9778
# AUC-ROC (micro-average): 0.9904

# %%
# Calculate True Positives, False Positives, False Negatives for each class
tp = np.diag(conf_matrix)
fp = np.sum(conf_matrix, axis=0) - tp
fn = np.sum(conf_matrix, axis=1) - tp
# Calculate True Negatives (TN) for each class
tn = []
for i in range(len(conf_matrix)):
    temp = np.delete(conf_matrix, i, 0)  # Remove ith row
    temp = np.delete(temp, i, 1)  # Remove ith column
    tn.append(np.sum(temp))

# Calculate Recall, Precision, and F1-score for each class
recall = tp / (tp + fn)
precision = tp / (tp + fp)
f1_score = 2 * (precision * recall) / (precision + recall)

# Calculate average Recall, Precision, and F1-score
macro_avg_recall = np.mean(recall)
macro_avg_precision = np.mean(precision)
macro_avg_f1_score = np.mean(f1_score)

print(f"Macro-average Recall: {macro_avg_recall:.4f}")
print(f"Macro-average Precision: {macro_avg_precision:.4f}")
print(f"Macro-average F1-score: {macro_avg_f1_score:.4f}")
# Out:
# Macro-average Recall: 0.9138
# Macro-average Precision: 0.9443
# Macro-average F1-score: 0.9283

# %%
# Calculate True Negatives for each class
tn = np.sum(conf_matrix) - (fp + fn + tp)

# Calculate Sensitivity (Recall) for each class
sensitivity = tp / (tp + fn)

# Calculate Specificity for each class
specificity = tn / (tn + fp)

# Calculate G-Mean for each class
g_mean = np.sqrt(sensitivity * specificity)

# Calculate average Sensitivity, Specificity, and G-Mean
avg_specificity = np.mean(specificity)
avg_g_mean = np.mean(g_mean)

print(f"Average Specificity: {avg_specificity:.4f}")
print(f"Average G-Mean: {avg_g_mean:.4f}")
# Out:
# Average Specificity: 0.9710
# Average G-Mean: 0.9417

# %%
def matthews_corr_coefficient(tp, tn, fp, fn):
    numerator = (tp * tn) - (fp * fn)
    denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
    mcc = numerator / denominator if denominator != 0 else 0  # Handle division by zero
    return mcc

# Calculate MCC for each class against the rest
mcc_per_class = []
for i in range(len(tp)):
    tp_i, tn_i = tp[i], np.sum(np.delete(tp, i))  # True positives and true negatives for class i
    fp_i, fn_i = fp[i], np.sum(np.delete(fp, i))  # False positives and false negatives for class i

    mcc_i = matthews_corr_coefficient(tp_i, tn_i, fp_i, fn_i)
    mcc_per_class.append(mcc_i)

# Calculate average MCC across all classes
mcc_avg = np.mean(mcc_per_class)
print("Average MCC:", mcc_avg)
# Out:
# Average MCC: 0.688755433933028
